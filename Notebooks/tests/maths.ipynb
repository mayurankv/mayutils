# %%
from numba import njit
import numpy as np

from mayutils.objects.mathematics.numba import choice_replacement


@njit
def foo(
    arr,
    seed,
):
    return choice_replacement(arr=arr, size=(10, 2), seed=seed)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>

# %%
# %%timeit


foo(np.array([0.1, 0.2, 0.3]), None)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
# label 0:
#     arr = arg(0, name=arr)                   ['arr']
#     seed = arg(1, name=seed)                 ['seed']
#     $4load_global.0 = global(choice_replacement: CPUDispatcher(<function choice_replacement at 0x1723df240>))
# ['$4load_global.0']
#     $const_10 = const(int, 10)               ['$const_10']
#     $const_2 = const(int, 2)                 ['$const_2']
#     $const16.3.1 = build_tuple(items=[Var($const_10, 874508412.py:12), Var($const_2, 874508412.py:12)])
# ['$const16.3.1', '$const_10', '$const_2']
#     $22call.5 = call $4load_global.0(func=$4load_global.0, args=[], kws=[('arr', Var(arr, 874508412.py:7)),
# ('size', Var($const16.3.1, 874508412.py:12)), ('seed', Var(seed, 874508412.py:7))], vararg=None, varkwarg=None,
# ...

# %%
import numba

print(numba.config.__dict__)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
# {
#     '__name__': 'numba.core.config',
#     '__doc__': None,
#     '__package__': 'numba.core',
#     '__loader__': <_frozen_importlib_external.SourceFileLoader object at 0x11fed4320>,
#     '__spec__': ModuleSpec(name='numba.core.config', loader=<_frozen_importlib_external.SourceFileLoader object at
# 0x11fed4320>,
# origin='/Users/mayuran.visakan/Documents/Pricing/Utilities/mayutils/.venv/lib/python3.12/site-packages/numba/core/c
# onfig.py'),
#     '__file__':
# '/Users/mayuran.visakan/Documents/Pricing/Utilities/mayutils/.venv/lib/python3.12/site-packages/numba/core/config.p
# y',
#     '__cached__':
# '/Users/mayuran.visakan/Documents/Pricing/Utilities/mayutils/.venv/lib/python3.12/site-packages/numba/core/__pycach
# e__/config.cpython-312.pyc',
#     '__builtins__': {
# ...
